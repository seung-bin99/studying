# %% [markdown]
# # 비지도 학습 소개

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# ## (1) 라이브러리 로딩

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## (2) Data Loading

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/customer_segmentation.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    CustID  Gender  Age  Income  Score
# 0       1    Male   19      15     39
# 1       2    Male   21      15     81
# 2       3  Female   20      16      6
# 3       4  Female   23      16     77
# 4       5  Female   31      17     40

# %% [markdown]
# # 2.데이터 전처리

# %% [markdown]
# ## (1) 데이터 분할

# %%
# 군집화는 아래 변수들만 사용합니다.
x = data.loc[:, ['Age', 'Income', 'Score']]

# %% [markdown]
# ## (2) 스케일링

# %%
scaler = MinMaxScaler()
x_s = scaler.fit_transform(x)

# %% [markdown]
# # 3.클러스터링

# %% [markdown]
# ## (1)  k-means 모델 만들기
# * k값을 늘려가면서(2~20) 모델을 만들고, inertia 값 혹은 실루엣 점수를 저장.
# * 그래프를 통해서 최적의 k값을 결정.
#     * 단, k값은 3~6개 사이에서 결정.
# * 선정된 k값으로 모델을 생성.

# %%
kvalues = range(1, 20)
inertias = []
for k in kvalues:
    model = KMeans(n_clusters=k, n_init='auto')
    model.fit(x_s)
    inertias.append(model.inertia_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(kvalues, inertias, marker='o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.grid()
plt.show()

# %%
from sklearn.metrics import *
kvalues = range(2, 20)
sil_score = []
for k in kvalues:
    model = KMeans(n_clusters=k, n_init='auto')
    pred = model.fit_predict(x_s)
    sil_score.append(silhouette_score(x, pred))

# %%
plt.figure(figsize=(8, 6))
plt.plot(kvalues, sil_score, marker='o')
plt.xlabel('number of clusters, k')
plt.ylabel('Silhouette score')
plt.grid()
plt.show()

# %% [markdown]
# - k = 5

# %% [markdown]
# ## (2) 데이터 군집 결과 정리
# * 데이터를 군집화 하여 기존 데이터와 합치기
#     * pd.concat([data, pred], axis = 1)

# %%
model = KMeans(n_clusters=5, n_init='auto', random_state=10)
model.fit(x_s)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=10)

# %%
# 예측
pred = model.predict(x_s)

# 예측 결과를 데이터프레임으로 만들고
pred = pd.DataFrame(pred, columns=['pred'])

# 원본 데이터와 합치기
result = pd.concat([data, pred], axis=1)

# 예측 결과는 카테고리 타입으로 변경 : 
result['pred'] = pd.Categorical(result['pred'])
result.head()
# Out:
#    CustID  Gender  Age  Income  Score pred
# 0       1    Male   19      15     39    4
# 1       2    Male   21      15     81    2
# 2       3  Female   20      16      6    4
# 3       4  Female   23      16     77    2
# 4       5  Female   31      17     40    4

# %% [markdown]
# # 4.후속 분석
# * 군집별 특징을 분석.

# %%
result
# Out:
#      CustID  Gender  Age  Income  Score pred
# 0         1    Male   19      15     39    4
# 1         2    Male   21      15     81    2
# 2         3  Female   20      16      6    4
# 3         4  Female   23      16     77    2
# 4         5  Female   31      17     40    4
# ..      ...     ...  ...     ...    ...  ...
# 195     196  Female   35     120     79    3
# 196     197  Female   45     126     28    0
# 197     198    Male   32     126     74    3
# 198     199    Male   32     137     18    0
# 199     200    Male   30     137     83    3
#
# [200 rows x 6 columns]

# %% [markdown]
# ## (1) 군집별 변수 비교
# * 활용 가능한 차트 : sns.barplot, sns.kdeplot, sns.boxplot, mosaic

# %% [markdown]
# ### 1) Age

# %%
var = 'Age'

plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
sns.barplot(x='pred', y=var, data=result)
plt.grid()

plt.subplot(1, 3, 2)
sns.kdeplot(x=var, data=result, hue='pred', common_norm=False)
plt.grid()

plt.subplot(1, 3, 3)
sns.boxplot(x=var, y='pred', data=result)
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2) Income

# %%
var = 'Income'

plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
sns.barplot(x='pred', y=var, data=result)
plt.grid()

plt.subplot(1, 3, 2)
sns.kdeplot(x=var, data=result, hue='pred', common_norm=False)
plt.grid()

plt.subplot(1, 3, 3)
sns.boxplot(x=var, y='pred', data=result)
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3) Score

# %%
var = 'Score'

plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
sns.barplot(x='pred', y=var, data=result)
plt.grid()

plt.subplot(1, 3, 2)
sns.kdeplot(x=var, data=result, hue='pred', common_norm=False)
plt.grid()

plt.subplot(1, 3, 3)
sns.boxplot(x=var, y='pred', data=result)
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4) Gender
# * 모자익 플롯을 사용.

# %%
from statsmodels.graphics.mosaicplot import mosaic

# %%
mosaic(result, ['pred', 'Gender'])
plt.show()

# %% [markdown]
# ## (2) 한꺼번에 비교하기
# * sns.pairplot을 이용하여 한꺼번에 비교.

# %%
# 'Age', 'Income', 'Score', 'pred'만 추출
cols = ['Age', 'Income', 'Score', 'pred']
temp = result.loc[:, cols]

# %%
sns.pairplot(temp, hue = 'pred')
plt.show()

# %% [markdown]
# ## (3) 각 군집별 특징을 정리
# * 각 군집의 특징(다른 군집과 차별화 되는 요소)을 정리.
# * 각 군집의 특징으로 볼 때, 어떤 고객군이라고 볼 수 있을까?
# * 각 고객군에 대한 적절한 마케팅 방법은?
# * 더 필요한 정보는?

# %% [markdown]
# - 군집0 / 노년 / 연간소득 높음 / 구매점수 낮음 / 전략: 프리미엄 실버, 공격적인 프로모션, 배달, 고급화
# - 군집1 / 노년 / 연간소득 중간 / 구매점수 중간 / 전략:
# - 군집2 / 젊은 / 연간소득 낮음 / 구매점수 높음 / 전략: 가성비, 배달, 구독, 할인판매, 쿠폰
# - 군집3 / 중년 / 연간소득 높음 / 구매점수 높음 / 전략:
# - 군집4 / 젊은 / 연간소득 중간 / 구매점수 중간 / 전략:
