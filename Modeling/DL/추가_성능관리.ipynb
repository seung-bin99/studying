# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
min_de = 0.001
pat = 5

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 115ms/step - loss: 0.6229 - val_loss: 0.5936
# Epoch 2/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5776 - val_loss: 0.5936
# Epoch 3/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5685 - val_loss: 0.5975
# Epoch 4/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5591 - val_loss: 0.5881
# Epoch 5/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5451 - val_loss: 0.5925
# Epoch 6/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5368 - val_loss: 0.5900
# Epoch 7/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5255 - val_loss: 0.5852
# Epoch 8/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5171 - val_loss: 0.5911
# Epoch 9/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5025 - val_loss: 0.5830
# Epoch 10/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4914 - val_loss: 0.5875
# Epoch 11/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4724 - val_loss: 0.5923
# Epoch 12/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4565 - val_loss: 0.5928
# Epoch 13/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4468 - val_loss: 0.5914
# Epoch 14/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4187 - val_loss: 0.5979

# %% [markdown]
# ## **3.가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.[참조]Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Dense(128, input_shape = (nfeatures,), activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 5.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.h5’)
#     * 딥러닝 모델의 메소드로 .save가 제공.
#     * 파일이름.h5 파일이 저장. (h5 파일 포맷 : 하둡파일 형식)

# %%
model.save('hanky.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야함
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능.

# %%
from keras.models import load_model
model2 = load_model('hanky.h5')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
pred2_1 = pred2.argmax(axis=1)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.7
# ------------------------------------------------------------
# [[35  0]
#  [15  0]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        35
#            1       0.00      0.00      0.00        15
#
#     accuracy                           0.70        50
#    macro avg       0.35      0.50      0.41        50
# weighted avg       0.49      0.70      0.58        50
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".h5"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)
# Out:
# Deleted: /content/030.h5
# Deleted: /content/003.h5
# Deleted: /content/001.h5
# Deleted: /content/041.h5
# Deleted: /content/006.h5
# Deleted: /content/045.h5
# Deleted: /content/037.h5
# Deleted: /content/002.h5
# Deleted: /content/004.h5
# Deleted: /content/044.h5
# Deleted: /content/036.h5
# Deleted: /content/033.h5
# Deleted: /content/005.h5

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Dense(64, input_shape = (nfeatures,), activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.h5'
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 [=====>........................] - ETA: 4s - loss: 0.6545
# Epoch 1: val_loss improved from inf to 0.63109, saving model to /content/001.h5
# 5/5 [==============================] - 1s 63ms/step - loss: 0.6334 - val_loss: 0.6311
# Epoch 2/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6302
# Epoch 2: val_loss improved from 0.63109 to 0.61808, saving model to /content/002.h5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6100 - val_loss: 0.6181
# Epoch 3/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6693
# Epoch 3: val_loss improved from 0.61808 to 0.60924, saving model to /content/003.h5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5926 - val_loss: 0.6092
# Epoch 4/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5862
# Epoch 4: val_loss improved from 0.60924 to 0.60260, saving model to /content/004.h5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5844 - val_loss: 0.6026
# Epoch 5/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6417
# Epoch 5: val_loss improved from 0.60260 to 0.59826, saving model to /content/005.h5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5764 - val_loss: 0.5983
# Epoch 6/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5341
# Epoch 6: val_loss improved from 0.59826 to 0.59444, saving model to /content/006.h5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5721 - val_loss: 0.5944
# Epoch 7/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6105
# Epoch 7: val_loss improved from 0.59444 to 0.59081, saving model to /content/007.h5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5667 - val_loss: 0.5908
# Epoch 8/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5731
# Epoch 8: val_loss improved from 0.59081 to 0.58926, saving model to /content/008.h5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5630 - val_loss: 0.5893
# Epoch 9/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6025
# Epoch 9: val_loss improved from 0.58926 to 0.58859, saving model to /content/009.h5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5600 - val_loss: 0.5886
# Epoch 10/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5417
# Epoch 10: val_loss improved from 0.58859 to 0.58808, saving model to /content/010.h5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5579 - val_loss: 0.5881
# Epoch 11/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4853
# Epoch 11: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5562 - val_loss: 0.5883
# Epoch 12/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5444
# Epoch 12: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5543 - val_loss: 0.5889
# Epoch 13/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5847
# Epoch 13: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5524 - val_loss: 0.5893
# Epoch 14/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5680
# Epoch 14: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5507 - val_loss: 0.5893
# Epoch 15/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5635
# Epoch 15: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5496 - val_loss: 0.5891
# Epoch 16/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4544
# Epoch 16: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5483 - val_loss: 0.5888
# Epoch 17/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6124
# Epoch 17: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5470 - val_loss: 0.5889
# Epoch 18/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4985
# Epoch 18: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5455 - val_loss: 0.5893
# Epoch 19/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5948
# Epoch 19: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5441 - val_loss: 0.5893
# Epoch 20/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4820
# Epoch 20: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5429 - val_loss: 0.5900
# Epoch 21/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4114
# Epoch 21: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5414 - val_loss: 0.5907
# Epoch 22/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5799
# Epoch 22: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5398 - val_loss: 0.5917
# Epoch 23/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5830
# Epoch 23: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5384 - val_loss: 0.5920
# Epoch 24/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5262
# Epoch 24: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5373 - val_loss: 0.5923
# Epoch 25/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5268
# Epoch 25: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5354 - val_loss: 0.5928
# Epoch 26/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5419
# Epoch 26: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5347 - val_loss: 0.5931
# Epoch 27/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4696
# Epoch 27: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5338 - val_loss: 0.5933
# Epoch 28/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5118
# Epoch 28: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5318 - val_loss: 0.5937
# Epoch 29/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4091
# Epoch 29: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5307 - val_loss: 0.5939
# Epoch 30/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5179
# Epoch 30: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5302 - val_loss: 0.5942
# Epoch 31/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5757
# Epoch 31: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5282 - val_loss: 0.5936
# Epoch 32/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5357
# Epoch 32: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5269 - val_loss: 0.5937
# Epoch 33/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6474
# Epoch 33: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5259 - val_loss: 0.5942
# Epoch 34/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6551
# Epoch 34: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5244 - val_loss: 0.5949
# Epoch 35/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5833
# Epoch 35: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5230 - val_loss: 0.5953
# Epoch 36/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4340
# Epoch 36: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5229 - val_loss: 0.5955
# Epoch 37/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5244
# Epoch 37: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5204 - val_loss: 0.5962
# Epoch 38/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4911
# Epoch 38: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5189 - val_loss: 0.5967
# Epoch 39/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4450
# Epoch 39: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5178 - val_loss: 0.5965
# Epoch 40/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4695
# Epoch 40: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5161 - val_loss: 0.5965
# Epoch 41/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5100
# Epoch 41: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5145 - val_loss: 0.5971
# Epoch 42/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4283
# Epoch 42: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5138 - val_loss: 0.5978
# Epoch 43/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5379
# Epoch 43: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5113 - val_loss: 0.5989
# Epoch 44/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6048
# Epoch 44: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5099 - val_loss: 0.5994
# Epoch 45/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4839
# Epoch 45: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5088 - val_loss: 0.5997
# Epoch 46/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5745
# Epoch 46: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5071 - val_loss: 0.6000
# Epoch 47/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4377
# Epoch 47: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5058 - val_loss: 0.6000
# Epoch 48/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5174
# Epoch 48: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5035 - val_loss: 0.6001
# Epoch 49/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3788
# Epoch 49: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5018 - val_loss: 0.6006
# Epoch 50/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6594
# Epoch 50: val_loss did not improve from 0.58808
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5023 - val_loss: 0.6012

# %%
# 학습결과 그래프
dl_history_plot(hist)
